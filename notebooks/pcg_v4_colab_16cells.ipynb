# %% [markdown]
# # PCG-MAS v4 Remote 16-Cell Runner
#
# Runs the large-model split: `Llama-3.3-70B × 8 datasets` and `DeepSeek-V3 × 8 datasets`.
# Outputs are written to Google Drive under `pcg-submission/results/v4_matrix/remote`.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !git clone https://github.com/anonymous-submission/proof-carrying-multi-agents.git pcg-submission || true
# %cd /content/pcg-submission
# !git pull
# !bash scripts/v4_colab_bootstrap.sh

# %% [markdown]
# ## Set Hugging Face token
# Use Colab secrets or paste temporarily for the session. Do not commit tokens.

# %%
import os
# Recommended: set via Colab Secrets and read it here.
# os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')
assert os.environ.get('HF_TOKEN'), 'Set HF_TOKEN before running remote cells.'

# %% [markdown]
# ## Preflight test one remote command

# %%
# !PYTHONPATH=src python scripts/v4_run_matrix_remote.py \
  --dry-run \
  --n-examples 3 \
  --seeds 0 \
  --datasets hotpotqa \
  --models deepseek-v3 \
  --experiments r1

# %% [markdown]
# ## Minimal real remote preflight
# Run this before launching the full remote matrix.

# %%
# !PYTHONPATH=src python scripts/v4_run_matrix_remote.py \
  --n-examples 3 \
  --seeds 0 \
  --datasets hotpotqa \
  --models deepseek-v3 \
  --experiments r1 \
  --out-root /content/drive/MyDrive/pcg-submission/results/v4_matrix/remote

# %% [markdown]
# ## Full 16-cell remote run
# Only run after the preflight test succeeds.

# %%
# !PYTHONPATH=src python scripts/v4_run_matrix_remote.py \
  --allow-full-run \
  --n-examples 50 \
  --seeds 0 \
  --experiments r1 r2 r3 r4 r5 \
  --out-root /content/drive/MyDrive/pcg-submission/results/v4_matrix/remote

# %% [markdown]
# ## Zip remote results for Mac reconciliation

# %%
# !cd /content/drive/MyDrive/pcg-submission && zip -r pcg_remote_results.zip results/v4_matrix/remote
